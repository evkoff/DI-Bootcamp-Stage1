# %% [markdown]
# # Exercises XP: Student Notebook
#
# For each exercise, the **Instructions** from the plateform are guided, and the **Guidance** explains exactly what you must do to complete the task.

# %% [markdown]
# ## What you will learn
# - How to clearly define and articulate a machine learning problem statement.
#
# - The process of data collection, including identifying relevant data types and potential data sources.
# Skills in feature selection and justification for machine learning models, particularly in the context of loan default prediction.
#
# - Understanding of different types of machine learning models and their suitability for various real-world scenarios.
#
# - Techniques and strategies for evaluating the performance of different machine learning models, including choosing appropriate metrics and understanding their implications.

# %% [markdown]
# ## What you will create
# - A detailed problem statement and data collection plan for a loan default prediction project, including identification of key data types and sources.
# - A comprehensive feature selection analysis for a hypothetical loan default prediction dataset.
# - A theoretical evaluation strategy for three different types of machine learning models, addressing the unique challenges and metrics relevant to each model type.
# - Thoughtful analyses and justifications for choosing specific machine learning approaches for varied scenarios such as stock price prediction, library organization, and robot navigation.
# - A document or presentation that showcases your understanding and approach to evaluating and optimizing machine learning models in diverse contexts.

# %% [markdown]
# ## 🌟 Exercise 1 : Defining the Problem and Data Collection for Loan Default Prediction
#
# ### Instructions
# - Write a clear problem statement for predicting loan defaults.
# - Identify and list the types of data you would need for this project (e.g., personal details of applicants, credit scores, loan amounts, repayment history).
# - Discuss the sources where you can collect this data (e.g., financial institution’s internal records, credit bureaus).
#
# **Expected Output:** A document detailing the problem statement and a comprehensive plan for data collection, including data types and sources.

# %% [markdown]
# ### Guidance
# - Please write your answer as a short document. Begin by stating the prediction objective in a complete sentence that names the target variable and the decision it will support. Then, describe the data types you would collect in complete sentences. For each data type, explain in one sentence why it could help predict loan defaults.
#
# - After that, name realistic data sources in complete sentences, and briefly describe how you would obtain or integrate each source.
#
# - Finally, include one paragraph that explains risks and constraints such as privacy, regulation, data quality, sampling bias, and governance.

# %% [markdown]
# ### Your answer
# > To-Do:
# Please write your full answer below using complete sentences and clear structure.

# %% [markdown]
# # Loan Default Prediction: Problem Statement and Data Collection Plan
#
# ## Problem Statement
#
# The objective of this project is to predict whether a loan applicant is likely to default on a loan. The target variable is loan default status (default or non-default). The prediction will help financial institutions make better lending decisions, reduce financial losses, and manage risk more effectively.
#
# ## Required Data Types
#
# ### Personal Information
# Applicant age, gender, marital status, and education level. These variables may help identify patterns associated with loan repayment behavior.
#
# ### Employment Information
# Employment status, occupation, employer type, and years of employment. Stable employment often indicates a greater ability to repay loans.
#
# ### Income Information
# Monthly or annual income and additional income sources. Income is a key indicator of a borrower's repayment capacity.
#
# ### Credit History
# Credit score, previous loans, repayment history, and past defaults. This information provides insight into the applicant’s financial reliability.
#
# ### Loan Information
# Loan amount, loan term, interest rate, and loan purpose. These characteristics directly influence repayment risk.
#
# ### Financial Obligations
# Existing debts, credit card balances, and debt-to-income ratio. High financial obligations may increase the likelihood of default.
#
# ### Banking Transactions
# Savings account balance, checking account balance, and transaction history. These data points provide information about financial stability and spending habits.
#
# ## Data Sources
#
# ### Financial Institution Internal Records
# Historical loan applications and repayment records can be collected from the bank’s internal databases.
#
# ### Credit Bureaus
# Credit scores and credit histories can be obtained from credit reporting agencies such as Experian, Equifax, or TransUnion.
#
# ### Customer Applications
# Personal, employment, and income information can be collected directly from loan application forms.
#
# ### Bank Statements
# Applicants may provide bank statements that can be integrated into the analysis to assess financial health.
#
# ### Government and Public Records
# Publicly available information may be used to verify identity, employment status, or other relevant details where legally permitted.
#
# ## Risks and Constraints
#
# Several risks and constraints must be considered during this project. Privacy regulations such as GDPR and other data protection laws require secure handling of personal information and customer consent. Data quality issues, including missing, inaccurate, or outdated information, may reduce model performance. Sampling bias can occur if the training data does not accurately represent the full population of loan applicants. Regulatory requirements may also limit the use of certain personal attributes in lending decisions. Strong data governance practices must be implemented to ensure data security, transparency, fairness, and compliance throughout the project.

# %% [markdown]
# ## 🌟 Exercise 2 : Feature Selection and Model Choice for Loan Default Prediction
#
# ### Instructions
# From this dataset, identify which features might be most relevant for predicting loan defaults.
# Justify your choice of features.

# %% [markdown]
# ### Guidance
# - First, identify the features that you believe are most relevant, and write their names in a sentence.
# Then, provide a justification in complete sentences that explains how each selected feature relates to the likelihood of default.
#
# - If you decide to exclude common features, write one sentence for each excluded feature to explain why it is not appropriate in this context.
#
# - Conclude with two complete sentences that explain how you would encode categorical features and how you would impute missing values.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It provides a simple template you can modify while writing your justification.

import pandas as pd

# This placeholder DataFrame allows the cell to run even if you did not load a dataset yet.
example_columns = [
    "age","employment_length","annual_income","credit_score","loan_amount","interest_rate",
    "debt_to_income","num_delinquencies","num_open_accounts","total_utilization","home_ownership",
    "purpose","term","application_type","state","zip_code"
]
df = pd.DataFrame(columns=example_columns)

# Please replace this list with the actual columns that you select.
selected_features = [
    # e.g., "credit_score","debt_to_income","annual_income","loan_amount","interest_rate",
    # "employment_length","num_delinquencies","total_utilization"
]

print("You will now justify the selected features in complete sentences below.")
# Out:
# You will now justify the selected features in complete sentences below.

# %% [markdown]
# ### Your justification
# > To-Do: Please write complete sentences that justify the relevance of each selected feature.
# If you excluded any common features, please state your reasons in complete sentences.
#
# Also explain, in two complete sentences, how you would encode categorical variables and how you would impute missing values.

# %% [markdown]
# The most relevant features for predicting loan default are credit_score, debt_to_income, annual_income, loan_amount, interest_rate, employment_length, num_delinquencies, and total_utilization.
#
# **Credit score** is one of the strongest predictors of default because it reflects an applicant's history of managing debt and making payments on time.
#
# **Debt-to-income** ratio is important because borrowers with a high level of debt relative to their income may struggle to meet additional loan obligations.
#
# **Annual income** helps estimate the applicant's ability to repay the loan. Higher income generally indicates a greater repayment capacity.
#
# **Loan amount** is relevant because larger loans typically represent a greater financial burden and may increase the risk of default.
#
# **Interest rate** is important because higher interest rates increase monthly payments and can make repayment more difficult.
#
# **Employment length** provides information about job stability. Applicants with longer employment histories often have more stable income sources.
#
# **Number of delinquencies** is highly relevant because previous late payments are often associated with future repayment problems.
#
# **Total credit utilization** indicates how much of the available credit is currently being used. High utilization may suggest financial stress and increased default risk.
#
# I would exclude state and zip_code because they may introduce geographic bias and are generally less directly related to an applicant's repayment ability. I would also exclude application_type because it may contribute less predictive value than financial and credit-related variables.
#
# Categorical variables such as home_ownership, purpose, and application_type would be encoded using one-hot encoding to convert them into numerical features suitable for machine learning models.
#
# Missing numerical values would be imputed using the median value, while missing categorical values would be filled with the most frequent category to preserve as much information as possible.

# %% [markdown]
# ## 🌟 Exercise 3 : Training, Evaluating, and Optimizing the Model
#
# ### Instructions
# Which model(s) would you pick for a Loan Prediction ?
# Outline the steps to evaluate the model’s performance, mentioning specific metrics that would be relevant to evaluate the model.

# %% [markdown]
# ### Guidance
# - Begin by naming one or two candidate models in a complete sentence and explain why each model is suitable for this problem.
#
# - Next, describe an evaluation plan in complete sentences that covers the data split, the cross-validation strategy, the metrics you will report, and how you will choose a decision threshold.
#
# - Then, explain in complete sentences how you will address class imbalance using stratification, class weights, or resampling.
#
# - Finally, state in one or two complete sentences how you would iterate on hyperparameters to improve performance while avoiding data leakage.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# It demonstrates standard classification metrics for binary loan default prediction.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score, confusion_matrix, classification_report

# Please replace these placeholders with your true labels and predicted probabilities.
y_true = [0,1,0,1,0,0,1,0,1,0]            # placeholder labels
y_pred_proba = [0.05,0.80,0.10,0.65,0.20,0.15,0.70,0.30,0.85,0.25]  # placeholder probabilities

# You should set a decision threshold that reflects the precision–recall trade-off for your business case.
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
print("\nConfusion matrix:\n", confusion_matrix(y_true, y_pred))
print("\nClassification report:\n", classification_report(y_true, y_pred, zero_division=0))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0
#
# Confusion matrix:
#  [[6 0]
#  [0 4]]
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         4
#
#     accuracy                           1.00        10
#    macro avg       1.00      1.00      1.00        10
# weighted avg       1.00      1.00      1.00        10

# %% [markdown]
# ### Your answer
# > To-Do: Please write complete sentences that explain your model choice, your evaluation plan, your approach to class imbalance, and your threshold selection strategy.

# %% [markdown]
# I would choose **Logistic Regression** and **Random Forest** as candidate models for loan default prediction. **Logistic Regression** is a strong baseline model because it is simple, interpretable, and provides probability estimates. **Random Forest** is also suitable because it can capture complex relationships between features and is less sensitive to outliers and feature interactions.
#
# I would split the dataset into **training, validation, and test sets** using **stratified sampling** to preserve the proportion of default and non-default cases. I would use **cross-validation** on the training data to evaluate model stability and reduce the risk of overfitting.
#
# The primary evaluation metrics would be **Precision, Recall, F1-Score, ROC-AUC, and PR-AUC**. **Recall** is particularly important because failing to identify a customer who is likely to default may result in significant financial losses. **F1-Score** provides a balance between Precision and Recall, while **ROC-AUC** and **PR-AUC** help evaluate model performance across different decision thresholds.
#
# The decision threshold would be selected based on **business objectives** and the trade-off between **Precision and Recall**. If minimizing default risk is the priority, I would choose a threshold that increases **Recall** while maintaining acceptable Precision.
#
# To address **class imbalance**, I would use **stratified sampling**, **class weights**, or resampling techniques such as **SMOTE**. These approaches help ensure that the model pays sufficient attention to the minority class of default cases.
#
# To improve performance, I would tune **hyperparameters** using **cross-validation** and **Grid Search** or **Randomized Search**. All preprocessing steps, feature engineering, and hyperparameter tuning would be performed only on the **training data** to avoid **data leakage** and ensure reliable evaluation results.

# %% [markdown]
# ## 🌟 Exercise 4 : Designing Machine Learning Solutions for Specific Problems
#
# ### Instructions
# For each of these scenario, decide which type of machine learning would be most suitable. Explain.
#
# Predicting Stock Prices : predict future prices
# Organizing a Library of Books : group books into genres or categories based on similarities.
# Program a robot to navigate and find the shortest path in a maze.

# %% [markdown]
# ### Guidance
# Please identify the appropriate machine learning paradigm for each scenario in complete sentences and justify your choice.
#
# For each scenario, write one complete sentence that describes the input data, one complete sentence that describes the output, and one complete sentence that describes the learning signal or objective.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below, using full sentences for each scenario.

# %% [markdown]
# ## 1. Predicting Stock Prices
#
# The most suitable machine learning paradigm for this problem is **Supervised Learning**, specifically a **Regression** model, because historical data and target values are available.
#
# **Input:** The input data would include historical stock prices, trading volume, market indicators, and economic factors.
#
# **Output:** The output would be the predicted future stock price or expected price movement.
#
# **Learning Objective:** The model learns from historical examples by minimizing the difference between predicted and actual stock prices.
#
# ---
#
# ## 2. Organizing a Library of Books
#
# The most suitable machine learning paradigm for this problem is **Unsupervised Learning**, specifically **Clustering**, because books can be grouped based on similarities without predefined labels.
#
# **Input:** The input data would include book titles, descriptions, keywords, authors, and other textual features.
#
# **Output:** The output would be groups or clusters of similar books that may correspond to genres or categories.
#
# **Learning Objective:** The model learns to identify patterns and similarities among books and organize them into meaningful clusters.
#
# ---
#
# ## 3. Programming a Robot to Navigate a Maze
#
# The most suitable machine learning paradigm for this problem is **Reinforcement Learning**, because the robot learns through interaction with its environment.
#
# **Input:** The input data would include the robot's current position, surrounding environment, available actions, and information about obstacles.
#
# **Output:** The output would be the next action or sequence of actions that guides the robot toward the goal.
#
# **Learning Objective:** The model learns by receiving rewards for successful navigation and penalties for inefficient or incorrect actions, with the goal of finding the shortest path through the maze.

# %% [markdown]
# ## 🌟 Exercise 5 : Designing an Evaluation Strategy for Different ML Models
#
# ### Instructions
# - Select three types of machine learning models: one from supervised learning (e.g., a classification model), one from unsupervised learning (e.g., a clustering model), and one from reinforcement learning. - For the supervised model, outline a strategy to evaluate its performance, including the choice of metrics (like accuracy, precision, recall, F1-score) and methods (like cross-validation, ROC curves).
# - For the unsupervised model, describe how you would assess the effectiveness of the model, considering techniques like silhouette score, elbow method, or cluster validation metrics.
# - For the reinforcement learning model, discuss how you would measure its success, considering aspects like cumulative reward, convergence, and exploration vs. exploitation balance.
# - Address the challenges and limitations of evaluating models in each category.

# %% [markdown]
# ### Guidance
# - Please write a separate paragraph for each of the three model categories.
# - In the supervised paragraph, describe your validation plan and list the metrics you will report in complete sentences.
# - In the unsupervised paragraph, explain how you would measure cluster quality or structure in complete sentences and mention any diagnostic plots.
# - In the reinforcement learning paragraph, describe how you would track cumulative reward, assess convergence, and balance exploration and exploitation using complete sentences.
# Conclude with one complete sentence per category that states a key evaluation challenge.

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Supervised classification metrics template with placeholders.

from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, average_precision_score

# Replace these placeholders with your real outputs.
y_true = [0,1,1,0,1,0,0,1,0,1]
y_pred_proba = [0.1,0.7,0.8,0.2,0.6,0.3,0.4,0.9,0.2,0.85]
threshold = 0.5
y_pred = [1 if p >= threshold else 0 for p in y_pred_proba]

print("Accuracy:", round(accuracy_score(y_true, y_pred), 4))
print("Precision:", round(precision_score(y_true, y_pred, zero_division=0), 4))
print("Recall:", round(recall_score(y_true, y_pred, zero_division=0), 4))
print("F1-score:", round(f1_score(y_true, y_pred, zero_division=0), 4))
print("ROC-AUC:", round(roc_auc_score(y_true, y_pred_proba), 4))
print("PR-AUC (Average Precision):", round(average_precision_score(y_true, y_pred_proba), 4))
# Out:
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1-score: 1.0
# ROC-AUC: 1.0
# PR-AUC (Average Precision): 1.0

# %%
# This piece of code is already prefilled, run it to execute it and see the results.
# Unsupervised clustering metrics template with synthetic data.

from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

X, _ = make_blobs(n_samples=300, centers=3, random_state=42)
kmeans = KMeans(n_clusters=3, n_init="auto", random_state=42)
labels = kmeans.fit_predict(X)
sil = silhouette_score(X, labels)
print("Silhouette score (higher is better):", round(sil, 4))

print("Please explain in complete sentences when you would use the elbow method and how you would interpret it.")
# Out:
# Silhouette score (higher is better): 0.848
# Please explain in complete sentences when you would use the elbow method and how you would interpret it.

# %% [markdown]
# ### Your answer
# > To-Do: Please write your complete answers below as three paragraphs, one for supervised learning, one for unsupervised learning, and one for reinforcement learning.

# %% [markdown]
# ### Supervised Learning (Classification Model)
#
# For supervised learning, I would use a classification model such as Logistic Regression or Random Forest. I would split the data into training, validation, and test sets and apply cross-validation to evaluate the model's stability and generalization performance. The primary metrics would be Accuracy, Precision, Recall, F1-Score, ROC-AUC, and PR-AUC. I would also analyze the confusion matrix and ROC curve to better understand model performance across different thresholds. A key challenge in supervised learning is avoiding overfitting while maintaining strong performance on unseen data.
#
# ### Unsupervised Learning (Clustering Model)
#
# For unsupervised learning, I would use a clustering model such as K-Means. Since there are no target labels, I would evaluate the clustering quality using the Silhouette Score, which measures how well data points fit within their assigned clusters. I would also use the Elbow Method to determine the optimal number of clusters by analyzing the relationship between the number of clusters and within-cluster variance. Cluster visualizations and diagnostic plots would help assess cluster separation and structure. A key challenge in unsupervised learning is that there is often no definitive ground truth for evaluating cluster quality.
#
# ### Reinforcement Learning
#
# For reinforcement learning, I would evaluate the model based on cumulative reward over time. I would track whether the agent's reward consistently improves and whether the learning process converges to a stable policy. I would also monitor the balance between exploration and exploitation to ensure that the agent continues learning while taking advantage of successful strategies. Additional metrics could include task completion rate, average episode length, and success rate. A key challenge in reinforcement learning is that training can require many interactions with the environment and may be computationally expensive.
